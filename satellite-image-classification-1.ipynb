# %%
import kagglehub

path = kagglehub.dataset_download("mahmoudreda55/satellite-image-classification")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/satellite-image-classification

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
desert_folder = '/kaggle/input/satellite-image-classification/data/desert'
augmented_folder = '/kaggle/working/Desert_Augmented'
os.makedirs(augmented_folder, exist_ok=True)

# %%
all_images = sorted(os.listdir(desert_folder))
images_to_augment = all_images[::2][:369]

# %%
def rotate_image(image, angle):
    h, w = image.shape[:2]
    center = (w // 2, h // 2)
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))
    return rotated_image

def flip_image(image, horizontal=True):
    
    if horizontal:
        return cv2.flip(image, 1)
    else:
        return cv2.flip(image, 0)

for idx, img_name in enumerate(images_to_augment):
    img_path = os.path.join(desert_folder, img_name)
    
    image = cv2.imread(img_path)
    if image is None:
        print(f"Warning: Couldn't read {img_path}")
        continue
    
    rotated_image = rotate_image(image, angle=90)
    flipped_image = flip_image(rotated_image, horizontal=True)

    
    #cv2.imwrite(os.path.join(augmented_folder, f"desert_rotated_{idx}.jpg"), rotated_image)
    cv2.imwrite(os.path.join(augmented_folder, f"desert_flipped_{idx}.jpg"), flipped_image)

print("Augmentation completed. Augmented images saved to:", augmented_folder)
# Out:
# Augmentation completed. Augmented images saved to: /kaggle/working/Desert_Augmented

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import cv2

input_base_path = '/kaggle/input/satellite-image-classification/data'
augmented_path = '/kaggle/working/Desert_Augmented'
output_base_path = '/kaggle/working/prepared_dataset' 

categories = ['cloudy', 'desert', 'green_area', 'water']
split_ratios = {'train': 0.7, 'val': 0.15, 'test': 0.15}

def copy_images(image_list, source_folder, target_folder, augmented_images=None):

    for img in image_list:
        if augmented_images and img in augmented_images:
            src = os.path.join(augmented_path, img)
        else:
            src = os.path.join(source_folder, img)
        
        dest = os.path.join(target_folder, img)
        shutil.copy(src, dest)

# %%
for split in ['train', 'val', 'test']:
    for category in categories:
        os.makedirs(os.path.join(output_base_path, split, category), exist_ok=True)


for category in categories:
    if category == 'desert':
        desert_original = sorted(os.listdir(os.path.join(input_base_path, 'desert')))
        desert_augmented = sorted(os.listdir(augmented_path))
        all_images = desert_original + desert_augmented
    else:
        all_images = sorted(os.listdir(os.path.join(input_base_path, category)))
    
    
    train_images, temp_images = train_test_split(all_images, test_size=split_ratios['val'] + split_ratios['test'], random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=split_ratios['test'] / (split_ratios['val'] + split_ratios['test']), random_state=42)
    
    
    for split, image_list in zip(['train', 'val', 'test'], [train_images, val_images, test_images]):
        split_folder = os.path.join(output_base_path, split, category)
        copy_images(image_list, os.path.join(input_base_path, category), split_folder, desert_augmented if category == 'desert' else None)

print("Dataset preparation complete. Folders created at:", output_base_path)

for split in ['train', 'val', 'test']:
    print(f"\nChecking {split} data:")
    for category in os.listdir(os.path.join(output_base_path, split)):
        category_path = os.path.join(output_base_path, split, category)
        num_images = len(os.listdir(category_path))
        print(f"  {category}: {num_images} images")
# Out:
# Dataset preparation complete. Folders created at: /kaggle/working/prepared_dataset
#
# Checking train data:
#   green_area: 1050 images
#   desert: 1050 images
#   cloudy: 1050 images
#   water: 1050 images
#
# Checking val data:
#   green_area: 225 images
#   desert: 225 images
#   cloudy: 225 images
#   water: 225 images
#
# Checking test data:
#   green_area: 225 images
#   desert: 225 images
#   cloudy: 225 images
#   water: 225 images

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

model.compile(optimizer=Adam(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 15, 15, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 7, 7, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │       3,211,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,600,964 (13.74 MB)
#  Trainable params: 3,600,964 (13.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_dir = '/kaggle/working/prepared_dataset/train'
val_dir = '/kaggle/working/prepared_dataset/val'

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=32,
    label_mode='categorical'
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(150, 150),
    batch_size=32,
    label_mode='categorical'
)
# Out:
# Found 4200 files belonging to 4 classes.
# Found 900 files belonging to 4 classes.

# %%
early_stopping = EarlyStopping(
    monitor='val_accuracy',    
    patience=5,                
    mode='max',                
    restore_best_weights=True  
)

# Train the model with EarlyStopping
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,                
    callbacks=[early_stopping]
)
# Save the model
model.save('/kaggle/working/satellite_model_simple.h5')
print("Model saved successfully!")
# Out:
# Epoch 1/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.6944 - loss: 2.3970 - val_accuracy: 0.8778 - val_loss: 0.2571
# Epoch 2/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8642 - loss: 0.2933 - val_accuracy: 0.9189 - val_loss: 0.1880
# Epoch 3/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8794 - loss: 0.2790 - val_accuracy: 0.8922 - val_loss: 0.2458
# Epoch 4/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8908 - loss: 0.2395 - val_accuracy: 0.9100 - val_loss: 0.1916
# Epoch 5/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9159 - loss: 0.2010 - val_accuracy: 0.8989 - val_loss: 0.2039
# Epoch 6/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9076 - loss: 0.2165 - val_accuracy: 0.9122 - val_loss: 0.1802
# Epoch 7/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9035 - loss: 0.2123 - val_accuracy: 0.8978 - val_loss: 0.2084
# Epoch 8/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9291 - loss: 0.1779 - val_accuracy: 0.9233 - val_loss: 0.1582
# Epoch 9/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9201 - loss: 0.1900 - val_accuracy: 0.9122 - val_loss: 0.1804
# Epoch 10/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9213 - loss: 0.1781 - val_accuracy: 0.9089 - val_loss: 0.1854
# Epoch 11/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9249 - loss: 0.1856 - val_accuracy: 0.9456 - val_loss: 0.1159
# Epoch 12/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9346 - loss: 0.1637 - val_accuracy: 0.9278 - val_loss: 0.1303
# Epoch 13/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9413 - loss: 0.1353 - val_accuracy: 0.9256 - val_loss: 0.1779
# Epoch 14/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9403 - loss: 0.1441 - val_accuracy: 0.9122 - val_loss: 0.1830
# Epoch 15/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9414 - loss: 0.1431 - val_accuracy: 0.9578 - val_loss: 0.1067
# Epoch 16/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9682 - loss: 0.0819 - val_accuracy: 0.9800 - val_loss: 0.0666
# Epoch 17/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9453 - loss: 0.1325 - val_accuracy: 0.9344 - val_loss: 0.1088
# Epoch 18/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9573 - loss: 0.1004 - val_accuracy: 0.9878 - val_loss: 0.0558
# Epoch 19/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9805 - loss: 0.0571 - val_accuracy: 0.8756 - val_loss: 0.4000
# Epoch 20/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9520 - loss: 0.1225 - val_accuracy: 0.9122 - val_loss: 0.1685
# Epoch 21/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9415 - loss: 0.1413 - val_accuracy: 0.9844 - val_loss: 0.0674
# Epoch 22/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9770 - loss: 0.0628 - val_accuracy: 0.9878 - val_loss: 0.0370
# Epoch 23/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9715 - loss: 0.0829 - val_accuracy: 0.9911 - val_loss: 0.0355
# Epoch 24/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9760 - loss: 0.0631 - val_accuracy: 0.9333 - val_loss: 0.1067
# Epoch 25/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9825 - loss: 0.0492 - val_accuracy: 0.9933 - val_loss: 0.0328
# Epoch 26/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.
100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9812 - loss: 0.0510 - val_accuracy: 0.9911 - val_loss: 0.0330
# Epoch 61/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9922 - loss: 0.0248 - val_accuracy: 0.9822 - val_loss: 0.0668
# Epoch 62/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9961 - loss: 0.0093 - val_accuracy: 0.9922 - val_loss: 0.0340
# Epoch 63/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9968 - loss: 0.0084 - val_accuracy: 0.9933 - val_loss: 0.0235
# Epoch 64/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9921 - loss: 0.0364 - val_accuracy: 0.9933 - val_loss: 0.0205
# Epoch 65/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9966 - loss: 0.0086 - val_accuracy: 0.9900 - val_loss: 0.0393
# Epoch 66/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9998 - loss: 0.0041 - val_accuracy: 0.9878 - val_loss: 0.0318
# Epoch 67/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9961 - loss: 0.0084 - val_accuracy: 0.9889 - val_loss: 0.0329
# Epoch 68/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9856 - val_loss: 0.0354
# Epoch 69/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9966 - loss: 0.0085 - val_accuracy: 0.9333 - val_loss: 0.1973
# Epoch 70/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9931 - loss: 0.0149 - val_accuracy: 0.9867 - val_loss: 0.0576
# Epoch 71/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9889 - val_loss: 0.0334
# Epoch 72/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9984 - loss: 0.0057 - val_accuracy: 0.9833 - val_loss: 0.0602
# Epoch 73/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9956 - val_loss: 0.0148
# Epoch 74/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9989 - loss: 0.0024 - val_accuracy: 0.9933 - val_loss: 0.0249
# Epoch 75/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9927 - loss: 0.0320 - val_accuracy: 0.9922 - val_loss: 0.0209
# Epoch 76/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9900 - val_loss: 0.0394
# Epoch 77/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9945 - loss: 0.0152 - val_accuracy: 0.9900 - val_loss: 0.0266
# Epoch 78/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9944 - val_loss: 0.0191
# Epoch 79/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9974 - loss: 0.0061 - val_accuracy: 0.9922 - val_loss: 0.0218
# Epoch 80/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9956 - val_loss: 0.0180
# Epoch 81/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9954 - loss: 0.0083 - val_accuracy: 0.9911 - val_loss: 0.0296
# Epoch 82/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9933 - val_loss: 0.0257
# Epoch 83/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9922 - val_loss: 0.0370
# Epoch 84/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9956 - val_loss: 0.0246
# Epoch 85/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9992 - loss: 0.0017 - val_accuracy: 0.9922 - val_loss: 0.0298
# Epoch 86/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 1.0000 - loss: 5.1451e-04 - val_accuracy: 0.9922 - val_loss: 0.0275
# Epoch 87/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9789 - val_loss: 0.0706
# Epoch 88/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9609 - loss: 0.1431 - val_accuracy: 0.9956 - val_loss: 0.0241
# Epoch 89/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9824 - loss: 0.0453 - val_accuracy: 0.9733 - val_loss: 0.0807
# Epoch 90/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9937 - loss: 0.0141 - val_accuracy: 0.9911 - val_loss: 0.0338
# Epoch 91/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9942 - loss: 0.0197 - val_accuracy: 0.9922 - val_loss: 0.0321
# Epoch 92/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9933 - val_loss: 0.0208
# Epoch 93/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9933 - val_loss: 0.0276
# Epoch 94/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9956 - val_loss: 0.0201
# Epoch 95/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.9944 - val_loss: 0.0293
# Epoch 96/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9922 - val_loss: 0.0305
# Epoch 97/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9960 - loss: 0.0097 - val_accuracy: 0.9956 - val_loss: 0.0204
# Epoch 98/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9906 - loss: 0.0243 - val_accuracy: 0.9889 - val_loss: 0.0392
# Epoch 99/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9974 - loss: 0.0111 - val_accuracy: 0.9878 - val_loss: 0.0536
# Epoch 100/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9937 - loss: 0.0172 - val_accuracy: 0.9911 - val_loss: 0.0361
# Model saved successfully!

# %%
test_dir = '/kaggle/working/prepared_dataset/test'

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(150, 150),
    batch_size=32,
    label_mode='categorical'
)

test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Found 900 files belonging to 4 classes.
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9798 - loss: 0.1644
# Test Accuracy: 98.44%
